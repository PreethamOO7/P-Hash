# %% [markdown]
# app.py [-h] [-o {json,csv,excel}] [--folder-loc FOLDER_LOC]
#               [--proxy [PROXY]]
#               [-e [EXCLUDE_CATEGORIES [EXCLUDE_CATEGORIES ...]]]
#               [-i [INCLUDE_CATEGORIES [INCLUDE_CATEGORIES ...]]] --market
#               MARKET
# python app.py -o csv --market "Women's Ethnic Wear"

# %% [markdown]
# pyhton app.py -e ["Popular Markets","All Men's Wear","Winter Wear","Wedding Wear"] --market "Men's Wear"

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

from PIL import Image

import requests

from io import BytesIO

import time
import csv

# %%
def get_url(image_asset):

   image_asset = eval(image_asset)

   return image_asset["original"]["uri"]

def get_image(url):

   response = requests.get(url)

   im = Image.open(BytesIO(response.content)).convert("RGB")

   im.thumbnail(size = [500,500])

   #display(im)

   return im

# %%
data=pd.read_csv("../udaan_csv/Mens_Wear/Wedding Wear.json",sep="\t")
#data

# %%
data["new_path"] = "aaa"
data
# Out:
#           Market  CategoryName SubCategoryName    ProductName  \
# 0     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 1     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 2     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 3     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 4     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 5     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 6     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 7     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 8     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 9     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 10    Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 11    Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 12    Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 13    Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# ...

# %%
data.columns
# Out:
# Index(['Market', 'CategoryName', 'SubCategoryName', 'ProductName', 'Brand',
#        'Gst', 'GstPercent', 'HasExtraTaxes', 'HasNoAssortments',
#        'HasOnlyAssortments', 'HasOnlyUniformAssortments', 'InferredMoq',
#        'InferredMoqIsFor', 'IsBuyable', 'ListingBlockerResp', 'ListingId',
#        'ListingMoq', 'ListingOrSalesUnitImageAssets', 'ListingVideos',
#        'MaxMarginPercent', 'MaxMrpPaise', 'MaxPricePaise', 'MinMarginPercent',
#        'MinMrpPaise', 'MinPricePaise', 'MoqSummary', 'OrgCompact', 'OrgId',
#        'PlatformBlocked', 'PriceDiscount', 'PriceDiscountBps',
#        'PriceIncludesTax', 'PricesArePer', 'PrimaryImageAsset', 'SpecList',
#        'Status', 'Tags', 'Title', 'Vat', 'VatPercent', 'VerticalSummary'],
#       dtype='object')

# %%
data['OrgId']
# Out:
# 0       ORG2CNJ4W8XLTC4WFKCVMTFKF619X
# 1       ORG2CNJ4W8XLTC4WFKCVMTFKF619X
# 2       ORG60ZPRGMGYT8X14LN1EG9GG3TSH
# 3       ORG71D05CHZK5DRX4CY4R444GFW1R
# 4       ORGFKHWMGZ59SCH34E7QM5QWL8540
# 5       ORG60ZPRGMGYT8X14LN1EG9GG3TSH
# 6       ORG71D05CHZK5DRX4CY4R444GFW1R
# 7       ORG71D05CHZK5DRX4CY4R444GFW1R
# 8       ORG71D05CHZK5DRX4CY4R444GFW1R
# 9       ORGFKHWMGZ59SCH34E7QM5QWL8540
# 10      ORG71D05CHZK5DRX4CY4R444GFW1R
# 11      ORG71D05CHZK5DRX4CY4R444GFW1R
# 12      ORG2CNJ4W8XLTC4WFKCVMTFKF619X
# 13      ORG2CNJ4W8XLTC4WFKCVMTFKF619X
# 14      ORG60ZPRGMGYT8X14LN1EG9GG3TSH
# 15      ORG71D05CHZK5DRX4CY4R444GFW1R
# 16      ORGFKHWMGZ59SCH34E7QM5QWL8540
# 17      ORG60ZPRGMGYT8X14LN1EG9GG3TSH
# 18      ORG71D05CHZK5DRX4CY4R444GFW1R
# 19      ORG71D05CHZK5DRX4CY4R444GFW1R
# 20      ORG71D05CHZK5DRX4CY4R444GFW1R
# 21      ORGFKHWMGZ59SCH34E7QM5QWL8540
# 22      ORG71D05CHZK5DRX4CY4R444GFW1R
# 23      ORG71D05CHZK5DRX4CY4R444GFW1R
# 24      ORG2CNJ4W8XLTC4WFKCVMTFKF619X
# ...

# %%
data.drop_duplicates(subset=["OrgId"])
# Out:
#           Market  CategoryName    SubCategoryName        ProductName  \
# 0     Men's Wear  Wedding Wear      Suits for Men      Suits for Men
# 2     Men's Wear  Wedding Wear      Suits for Men      Suits for Men
# 3     Men's Wear  Wedding Wear      Suits for Men      Suits for Men
# 4     Men's Wear  Wedding Wear      Suits for Men      Suits for Men
# 156   Men's Wear  Wedding Wear     Kurta Pyjamas      Kurta Pyjamas
# 157   Men's Wear  Wedding Wear     Kurta Pyjamas      Kurta Pyjamas
# 158   Men's Wear  Wedding Wear     Kurta Pyjamas      Kurta Pyjamas
# 162   Men's Wear  Wedding Wear     Kurta Pyjamas      Kurta Pyjamas
# 163   Men's Wear  Wedding Wear     Kurta Pyjamas      Kurta Pyjamas
# 4057  Men's Wear  Wedding Wear          Sherwanis          Sherwanis
# 4058  Men's Wear  Wedding Wear          Sherwanis          Sherwanis
# 4059  Men's Wear  Wedding Wear          Sherwanis          Sherwanis
# 4060  Men's Wear  Wedding Wear          Sherwanis          Sherwanis
# ...

# %%
# %%time
for i in range(3999,9828):
    ima= get_image(get_url(data["PrimaryImageAsset"].loc[i]))
    if(i%100==0):
        data.to_csv("../udaan_csv/Mens_Wear/Wedding_Wear_with_new_path.csv",index=False)
        print(i)
        
    f = "F:\\PICS\\"+"pic_" + str(i)  + ".jpg"
    ima.save(f)
    data["new_path"].loc[i] = f
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# Wall time: 34min 24s

# %%
data.to_csv("../udaan_csv/Mens_Wear/Wedding_Wear_with_new_path.csv",index=False)

# %%
data['PrimaryImageAsset'][567]
# Out:
# "{'id': 'u/products/KJPLBQX09SJ5H4HCR4S5ZX4T1G.jpg/1440/1080', 'original': {'uri': 'https://udaan.azureedge.net/products/KJPLBQX09SJ5H4HCR4S5ZX4T1G.jpg', 'width': 1440, 'height': 1080}, 'variants': [{'uri': 'https://ud-img.azureedge.net/t_im_w768/u/products/KJPLBQX09SJ5H4HCR4S5ZX4T1G.jpg', 'width': 768, 'height': 576}, {'uri': 'https://ud-img.azureedge.net/t_im_w480/u/products/KJPLBQX09SJ5H4HCR4S5ZX4T1G.jpg', 'width': 480, 'height': 360}, {'uri': 'https://ud-img.azureedge.net/t_im_w240/u/products/KJPLBQX09SJ5H4HCR4S5ZX4T1G.jpg', 'width': 240, 'height': 180}, {'uri': 'https://ud-img.azureedge.net/t_im_h1024/u/products/KJPLBQX09SJ5H4HCR4S5ZX4T1G.jpg', 'width': 1366, 'height': 1024}, {'uri': 'https://ud-img.azureedge.net/t_im_h640/u/products/KJPLBQX09SJ5H4HCR4S5ZX4T1G.jpg', 'width': 854, 'height': 640}, {'uri': 'https://ud-img.azureedge.net/t_im_h320/u/products/KJPLBQX09SJ5H4HCR4S5ZX4T1G.jpg', 'width': 427, 'height': 320}]}"

# %%
df=pd.DataFrame(data)
pathname=[]
for i in range(9828):
    pathname.append('pathname')
df['Pathname'] = pathname
df
# Out:
#           Market  CategoryName SubCategoryName    ProductName  \
# 0     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 1     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 2     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 3     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 4     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 5     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 6     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 7     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 8     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 9     Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 10    Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 11    Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 12    Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# 13    Men's Wear  Wedding Wear   Suits for Men  Suits for Men
# ...
