# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

from PIL import Image

import requests

from io import BytesIO

import time
import csv

# %%
def get_url(image_asset):

   image_asset = eval(image_asset)

   return image_asset["original"]["uri"]

def get_image(url):

   response = requests.get(url)

   im = Image.open(BytesIO(response.content)).convert("RGB")

   im.thumbnail(size = [500,500])

   #display(im)

   return im

# %%
data=pd.read_csv("../udaan_csv/Mens_Wear/Men s Wear.json",sep="\t")
data
# Out:
#              Market     CategoryName   SubCategoryName       ProductName  \
# 0        Men's Wear  Popular Markets  Kothwadi- Mumbai  Kothwadi- Mumbai
# 1        Men's Wear  Popular Markets  Kothwadi- Mumbai  Kothwadi- Mumbai
# 2        Men's Wear  Popular Markets  Kothwadi- Mumbai  Kothwadi- Mumbai
# 3        Men's Wear  Popular Markets  Kothwadi- Mumbai  Kothwadi- Mumbai
# 4        Men's Wear  Popular Markets  Kothwadi- Mumbai  Kothwadi- Mumbai
# 5        Men's Wear  Popular Markets  Kothwadi- Mumbai  Kothwadi- Mumbai
# 6        Men's Wear  Popular Markets  Kothwadi- Mumbai  Kothwadi- Mumbai
# 7        Men's Wear  Popular Markets  Kothwadi- Mumbai  Kothwadi- Mumbai
# 8        Men's Wear  Popular Markets  Kothwadi- Mumbai  Kothwadi- Mumbai
# 9        Men's Wear  Popular Markets  Kothwadi- Mumbai  Kothwadi- Mumbai
# 10       Men's Wear  Popular Markets  Kothwadi- Mumbai  Kothwadi- Mumbai
# 11       Men's Wear  Popular Markets  Kothwadi- Mumbai  Kothwadi- Mumbai
# ...

# %%
df=data.drop_duplicates(subset=["PrimaryImageAsset"])
df
# Out:
#              Market     CategoryName     SubCategoryName       ProductName  \
# 0        Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 1        Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 2        Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 3        Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 4        Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 5        Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 6        Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 7        Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 8        Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 9        Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 10       Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# ...

# %%
df['new_path']='aaa'
df
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#              Market     CategoryName     SubCategoryName       ProductName  \
# 0        Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 1        Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 2        Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 3        Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 4        Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 5        Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# ...

# %%
df=df.reset_index(drop='False',inplace=False)

# %%
df
# Out:
#          Market     CategoryName     SubCategoryName       ProductName  \
# 0    Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 1    Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 2    Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 3    Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 4    Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 5    Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 6    Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 7    Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 8    Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 9    Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 10   Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# 11   Men's Wear  Popular Markets    Kothwadi- Mumbai  Kothwadi- Mumbai
# ...

# %%
# %%time
for i in range(900,908):
    ima= get_image(get_url(df["PrimaryImageAsset"].loc[i]))
    if(i%100==0):
        df.to_csv("../udaan_csv/Mens_Wear/Mens_Wear_with_new_path.csv",index=False)
        print(i)
        
    f = "F:\\908_PICS\\"+"pic_" + str(i)  + ".jpg"
    ima.save(f)
    df['new_path'].loc[i] = f
# Out:
# 900
# C:\Users\dell\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Wall time: 7.14 s

# %%
df.to_csv("../udaan_csv/Mens_Wear/Mens_Wear_with_new_path.csv",index=False)

# %%
get_image(get_url(df["PrimaryImageAsset"].loc[899]))
#f = "F:\\908_PICS\\"+"pic_" + str(i)  + ".jpg"
#ima.save(f)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-55-b82d19841808> in <module>
# ----> 1 get_image(get_url(df["PrimaryImageAsset"].loc[899]))
#       2 #f = "F:\\908_PICS\\"+"pic_" + str(i)  + ".jpg"
#       3 #ima.save(f)
#
# <ipython-input-2-102333e0e37d> in get_image(url)
#       9    response = requests.get(url)
#      10
# ---> 11    im = Image.open(BytesIO(response.content)).convert("RGB")
#      12
#      13    im.thumbnail(size = [500,500])
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2703         warnings.warn(message)
#    2704     raise IOError("cannot identify image file %r"
# -> 2705                   % (filename if filename else fp))
#    2706
#    2707 #
#
# OSError: cannot identify image file <_io.BytesIO object at 0x00000263913C90A0>

# %%
get_url(df['PrimaryImageAsset'][899])
# Out:
# 'https://udaan.azureedge.net/products/nktln5o8c4nwbkbef62j.webp'
